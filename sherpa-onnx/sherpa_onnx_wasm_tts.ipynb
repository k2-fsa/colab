# %% [markdown]
# <a href="https://colab.research.google.com/github/csukuangfj/colab/blob/master/sherpa_onnx_wasm_tts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WebAssembly for TTS (sherpa-onnx)
#
# This colab notebook shows you how to run
# https://k2-fsa.github.io/sherpa/onnx/tts/wasm/index.html

# %% [markdown]
# ## Install Emscripten

# %%
# %%shell
#
# git clone https://github.com/emscripten-core/emsdk.git
# cd emsdk
# git pull
# ./emsdk install latest
# ./emsdk activate latest
# source ./emsdk_env.sh
#
# emcc -v
# Out:
# Cloning into 'emsdk'...
# remote: Enumerating objects: 4041, done.
# remote: Counting objects: 100% (607/607), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 4041 (delta 567), reused 525 (delta 515), pack-reused 3434
# Receiving objects: 100% (4041/4041), 2.19 MiB | 5.38 MiB/s, done.
# Resolving deltas: 100% (2655/2655), done.
# Already up to date.
# Resolving SDK alias 'latest' to '3.1.60'
# Resolving SDK version '3.1.60' to 'sdk-releases-87709b5747de5b1993fe314285528bf4b65c23e1-64bit'
# Installing SDK 'sdk-releases-87709b5747de5b1993fe314285528bf4b65c23e1-64bit'..
# Installing tool 'node-16.20.0-64bit'..
# Downloading: /content/emsdk/downloads/node-v16.20.0-linux-x64.tar.xz from https://storage.googleapis.com/webassembly/emscripten-releases-builds/deps/node-v16.20.0-linux-x64.tar.xz, 22559772 Bytes
# Unpacking '/content/emsdk/downloads/node-v16.20.0-linux-x64.tar.xz' to '/content/emsdk/node/16.20.0_64bit'
# Done installing tool 'node-16.20.0-64bit'.
# Installing tool 'releases-87709b5747de5b1993fe314285528bf4b65c23e1-64bit'..
# Downloading: /content/emsdk/downloads/87709b5747de5b1993fe314285528bf4b65c23e1-wasm-binaries.tar.xz from https://storage.googleapis.com/webassembly/emscripten-releases-builds/linux/87709b5747de5b1993fe314285528bf4b65c23e1/wasm-binaries.tar.xz, 297103804 Bytes
# Unpacking '/content/emsdk/downloads/87709b5747de5b1993fe314285528bf4b65c23e1-wasm-binaries.tar.xz' to '/content/emsdk/upstream'
# Done installing tool 'releases-87709b5747de5b1993fe314285528bf4b65c23e1-64bit'.
# Done installing SDK 'sdk-releases-87709b5747de5b1993fe314285528bf4b65c23e1-64bit'.
# Resolving SDK alias 'latest' to '3.1.60'
# Resolving SDK version '3.1.60' to 'sdk-releases-87709b5747de5b1993fe314285528bf4b65c23e1-64bit'
# Setting the following tools as active:
#    node-16.20.0-64bit
#    releases-87709b5747de5b1993fe314285528bf4b65c23e1-64bit
#
# Next steps:
# - To conveniently access emsdk tools from the command line,
#   consider adding the following directories to your PATH:
#     /content/emsdk
#     /content/emsdk/upstream/emscripten
# - This can be done for the current shell by running:
#     source "/content/emsdk/emsdk_env.sh"
# - Configure emsdk in your shell startup scripts by running:
#     echo 'source "/content/emsdk/emsdk_env.sh"' >> $HOME/.bash_profile
# Setting up EMSDK environment (suppress these messages with EMSDK_QUIET=1)
# Adding directories to PATH:
# PATH += /content/emsdk
# PATH += /content/emsdk/upstream/emscripten
#
# Setting environment variables:
# PATH = /content/emsdk:/content/emsdk/upstream/emscripten:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# EMSDK = /content/emsdk
# EMSDK_NODE = /content/emsdk/node/16.20.0_64bit/bin/node
# emcc (Emscripten gcc/clang-like replacement + linker emulating GNU ld) 3.1.60 (42a6ea2052f19f70d7d994e8c324bcad2f1f8939)
# clang version 19.0.0git (https:/github.com/llvm/llvm-project bc9823cf60bf91cc8b45248c4205cd2c67b2a3d5)
# Target: wasm32-unknown-emscripten
# Thread model: posix
# InstalledDir: /content/emsdk/upstream/bin

# %% [markdown]
# ## Build

# %%
# %%shell
#
# pushd ./emsdk
# source ./emsdk_env.sh
# popd
#
#
# git clone https://github.com/k2-fsa/sherpa-onnx
# cd sherpa-onnx
#
# cd wasm/tts/assets
#
# wget -q https://github.com/k2-fsa/sherpa-onnx/releases/download/tts-models/vits-piper-en_US-libritts_r-medium.tar.bz2
# tar xf vits-piper-en_US-libritts_r-medium.tar.bz2
# rm vits-piper-en_US-libritts_r-medium.tar.bz2
# mv vits-piper-en_US-libritts_r-medium/en_US-libritts_r-medium.onnx ./model.onnx
# mv vits-piper-en_US-libritts_r-medium/tokens.txt ./
# mv vits-piper-en_US-libritts_r-medium/espeak-ng-data ./
# rm -rf vits-piper-en_US-libritts_r-medium
#
# cd ../../..
#
# ./build-wasm-simd-tts.sh
# Out:
# /content/emsdk /content
# Setting up EMSDK environment (suppress these messages with EMSDK_QUIET=1)
# Adding directories to PATH:
# PATH += /content/emsdk
# PATH += /content/emsdk/upstream/emscripten
#
# Setting environment variables:
# PATH = /content/emsdk:/content/emsdk/upstream/emscripten:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# EMSDK = /content/emsdk
# EMSDK_NODE = /content/emsdk/node/16.20.0_64bit/bin/node
# /content
# Cloning into 'sherpa-onnx'...
# remote: Enumerating objects: 10409, done.
# remote: Counting objects: 100% (1003/1003), done.
# remote: Compressing objects: 100% (541/541), done.
# remote: Total 10409 (delta 553), reused 786 (delta 439), pack-reused 9406
# Receiving objects: 100% (10409/10409), 4.36 MiB | 8.71 MiB/s, done.
# Resolving deltas: 100% (6595/6595), done.
# + '[' x == x ']'
# + command -v emcc
# ++++ which emcc
# +++ realpath /content/emsdk/upstream/emscripten/emcc
# ++ dirname /content/emsdk/upstream/emscripten/emcc
# + EMSCRIPTEN=/content/emsdk/upstream/emscripten
# + export EMSCRIPTEN=/content/emsdk/upstream/emscripten
# + EMSCRIPTEN=/content/emsdk/upstream/emscripten
# + echo 'EMSCRIPTEN: /content/emsdk/upstream/emscripten'
# EMSCRIPTEN: /content/emsdk/upstream/emscripten
# + '[' '!' -f /content/emsdk/upstream/emscripten/cmake/Modules/Platform/Emscripten.cmake ']'
# + mkdir -p build-wasm-simd-tts
# + pushd build-wasm-simd-tts
# /content/sherpa-onnx/build-wasm-simd-tts /content/sherpa-onnx
# + export SHERPA_ONNX_IS_USING_BUILD_WASM_SH=ON
# + SHERPA_ONNX_IS_USING_BUILD_WASM_SH=ON
# + cmake -DCMAKE_INSTALL_PREFIX=./install -DCMAKE_BUILD_TYPE=Release -DCMAKE_TOOLCHAIN_FILE=/content/emsdk/upstream/emscripten/cmake/Modules/Platform/Emscripten.cmake -DSHERPA_ONNX_ENABLE_PYTHON=OFF -DSHERPA_ONNX_ENABLE_TESTS=OFF -DSHERPA_ONNX_ENABLE_CHECK=OFF -DBUILD_SHARED_LIBS=OFF -DSHERPA_ONNX_ENABLE_PORTAUDIO=OFF -DSHERPA_ONNX_ENABLE_JNI=OFF -DSHERPA_ONNX_ENABLE_C_API=ON -DSHERPA_ONNX_ENABLE_WEBSOCKET=OFF -DSHERPA_ONNX_ENABLE_GPU=OFF -DSHERPA_ONNX_ENABLE_WASM=ON -DSHERPA_ONNX_ENABLE_WASM_TTS=ON -DSHERPA_ONNX_ENABLE_BINARY=OFF -DSHERPA_ONNX_LINK_LIBSTDCPP_STATICALLY=OFF ..
# -- CMAKE_BUILD_TYPE: Release
# -- CMAKE_INSTALL_PREFIX: /content/sherpa-onnx/build-wasm-simd-tts/install
# -- BUILD_SHARED_LIBS OFF
# -- SHERPA_ONNX_ENABLE_PYTHON OFF
# -- SHERPA_ONNX_ENABLE_TESTS OFF
# -- SHERPA_ONNX_ENABLE_CHECK OFF
# -- SHERPA_ONNX_ENABLE_PORTAUDIO OFF
# -- SHERPA_ONNX_ENABLE_JNI OFF
# -- SHERPA_ONNX_ENABLE_C_API ON
# -- SHERPA_ONNX_ENABLE_WEBSOCKET OFF
# -- SHERPA_ONNX_ENABLE_GPU OFF
# -- SHERPA_ONNX_ENABLE_WASM ON
# -- SHERPA_ONNX_ENABLE_WASM_TTS ON
# -- SHERPA_ONNX_ENABLE_WASM_ASR OFF
# -- SHERPA_ONNX_ENABLE_WASM_KWS OFF
# -- SHERPA_ONNX_ENABLE_WASM_NODEJS OFF
# -- SHERPA_ONNX_ENABLE_BINARY OFF
# -- SHERPA_ONNX_ENABLE_TTS ON
# -- SHERPA_ONNX_LINK_LIBSTDCPP_STATICALLY OFF
# -- SHERPA_ONNX_USE_PRE_INSTALLED_ONNXRUNTIME_IF_AVAILABLE ON
# -- TTS is enabled
# -- C++ Standard version: 14
# -- Looking for C++ include cxxabi.h
# -- Looking for C++ include cxxabi.h - found
# -- Looking for C++ include execinfo.h
# -- Looking for C++ include execinfo.h - not found
# -- Downloading kaldi-native-fbank from https://github.com/csukuangfj/kaldi-native-fbank/archive/refs/tags/v1.19.1.tar.gz
# -- kaldi-native-fbank is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_native_fbank-src
# -- kaldi-native-fbank's binary dir is /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_native_fbank-build
# CMake Deprecation Warning at build-wasm-simd-tts/_deps/kaldi_native_fbank-src/CMakeLists.txt:24 (cmake_minimum_required):
#   Compatibility with CMake < 3.5 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value or use a ...<max> suffix to tell
#   CMake that the project does not need compatibility with older versions.
#
#
# -- CMAKE_BUILD_TYPE: Release
# -- CMAKE_EXPORT_COMPILE_COMMANDS:
# -- BUILD_SHARED_LIBS: OFF
# -- KALDI_NATIVE_FBANK_BUILD_TESTS: OFF
# -- KALDI_NATIVE_FBANK_BUILD_PYTHON: OFF
# -- KALDI_NATIVE_FBANK_ENABLE_CHECK: OFF
# -- KALDI_NATIVE_FBANK_ENABLE_CHECK: OFF
# -- CMAKE_CXX_FLAGS:
# -- CMAKE_INSTALL_PREFIX: /content/sherpa-onnx/build-wasm-simd-tts/install
# -- Looking for C++ include cxxabi.h
# -- Looking for C++ include cxxabi.h - found
# -- Looking for C++ include execinfo.h
# -- Looking for C++ include execinfo.h - not found
# -- Disable building Python
# -- Downloading kaldi-decoder from https://github.com/k2-fsa/kaldi-decoder/archive/refs/tags/v0.2.5.tar.gz
# -- kaldi-decoder is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-src
# -- kaldi-decoder's binary dir is /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-build
# -- CMAKE_BUILD_TYPE: Release
# -- Downloading kaldifst from https://github.com/k2-fsa/kaldifst/archive/refs/tags/v1.7.10.tar.gz
# -- kaldifst is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldifst-src
# -- kaldifst's binary dir is /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldifst-build
# -- CMAKE_BUILD_TYPE: Release
# -- CMAKE_BUILD_TYPE: Release
# -- CMAKE_INSTALL_PREFIX: /content/sherpa-onnx/build-wasm-simd-tts/install
# -- BUILD_SHARED_LIBS OFF
# -- C++ Standard version: 14
# -- CMAKE_CXX_FLAGS:
# -- Downloading openfst from https://github.com/csukuangfj/openfst/archive/refs/tags/sherpa-onnx-2024-05-22-2.tar.gz
# -- openfst is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src
# -- The following ICU libraries were not found:
# --   data (required)
# --   i18n (required)
# --   io (required)
# --   test (required)
# --   tu (required)
# --   uc (required)
# -- Failed to find all ICU components (missing: ICU_INCLUDE_DIR ICU_LIBRARY _ICU_REQUIRED_LIBS_FOUND)
# -- Could NOT find ZLIB (missing: ZLIB_LIBRARY ZLIB_INCLUDE_DIR)
# CMake Deprecation Warning at build-wasm-simd-tts/_deps/openfst-src/CMakeLists.txt:15 (cmake_minimum_required):
#   Compatibility with CMake < 3.5 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value or use a ...<max> suffix to tell
#   CMake that the project does not need compatibility with older versions.
#
#
# -- Downloading eigen from https://gitlab.com/libeigen/eigen/-/archive/3.4.0/eigen-3.4.0.tar.gz
# -- eigen is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/eigen-src
# -- eigen's binary dir is /content/sherpa-onnx/build-wasm-simd-tts/_deps/eigen-build
# -- Performing Test EIGEN_COMPILER_SUPPORT_CPP11
# -- Performing Test EIGEN_COMPILER_SUPPORT_CPP11 - Success
# -- Performing Test COMPILER_SUPPORT_std=cpp03
# -- Performing Test COMPILER_SUPPORT_std=cpp03 - Success
# -- Performing Test standard_math_library_linked_to_automatically
# -- Performing Test standard_math_library_linked_to_automatically - Success
# -- Standard libraries to link to explicitly: none
# -- Performing Test COMPILER_SUPPORT_WERROR
# -- Performing Test COMPILER_SUPPORT_WERROR - Success
# -- Performing Test COMPILER_SUPPORT_pedantic
# -- Performing Test COMPILER_SUPPORT_pedantic - Success
# -- Performing Test COMPILER_SUPPORT_Wall
# -- Performing Test COMPILER_SUPPORT_Wall - Success
# -- Performing Test COMPILER_SUPPORT_Wextra
# -- Performing Test COMPILER_SUPPORT_Wextra - Success
# -- Performing Test COMPILER_SUPPORT_Wundef
# -- Performing Test COMPILER_SUPPORT_Wundef - Success
# -- Performing Test COMPILER_SUPPORT_Wcastalign
# -- Performing Test COMPILER_SUPPORT_Wcastalign - Success
# -- Performing Test COMPILER_SUPPORT_Wcharsubscripts
# -- Performing Test COMPILER_SUPPORT_Wcharsubscripts - Success
# -- Performing Test COMPILER_SUPPORT_Wnonvirtualdtor
# -- Performing Test COMPILER_SUPPORT_Wnonvirtualdtor - Success
# -- Performing Test COMPILER_SUPPORT_Wunusedlocaltypedefs
# -- Performing Test COMPILER_SUPPORT_Wunusedlocaltypedefs - Success
# -- Performing Test COMPILER_SUPPORT_Wpointerarith
# -- Performing Test COMPILER_SUPPORT_Wpointerarith - Success
# -- Performing Test COMPILER_SUPPORT_Wwritestrings
# -- Performing Test COMPILER_SUPPORT_Wwritestrings - Success
# -- Performing Test COMPILER_SUPPORT_Wformatsecurity
# -- Performing Test COMPILER_SUPPORT_Wformatsecurity - Success
# -- Performing Test COMPILER_SUPPORT_Wshorten64to32
# -- Performing Test COMPILER_SUPPORT_Wshorten64to32 - Success
# -- Performing Test COMPILER_SUPPORT_Wlogicalop
# -- Performing Test COMPILER_SUPPORT_Wlogicalop - Failed
# -- Performing Test COMPILER_SUPPORT_Wenumconversion
# -- Performing Test COMPILER_SUPPORT_Wenumconversion - Success
# -- Performing Test COMPILER_SUPPORT_Wcpp11extensions
# -- Performing Test COMPILER_SUPPORT_Wcpp11extensions - Success
# -- Performing Test COMPILER_SUPPORT_Wdoublepromotion
# -- Performing Test COMPILER_SUPPORT_Wdoublepromotion - Success
# -- Performing Test COMPILER_SUPPORT_Wshadow
# -- Performing Test COMPILER_SUPPORT_Wshadow - Success
# -- Performing Test COMPILER_SUPPORT_Wnopsabi
# -- Performing Test COMPILER_SUPPORT_Wnopsabi - Success
# -- Performing Test COMPILER_SUPPORT_Wnovariadicmacros
# -- Performing Test COMPILER_SUPPORT_Wnovariadicmacros - Success
# -- Performing Test COMPILER_SUPPORT_Wnolonglong
# -- Performing Test COMPILER_SUPPORT_Wnolonglong - Success
# -- Performing Test COMPILER_SUPPORT_fnochecknew
# -- Performing Test COMPILER_SUPPORT_fnochecknew - Success
# -- Performing Test COMPILER_SUPPORT_fnocommon
# -- Performing Test COMPILER_SUPPORT_fnocommon - Success
# -- Performing Test COMPILER_SUPPORT_fstrictaliasing
# -- Performing Test COMPILER_SUPPORT_fstrictaliasing - Success
# -- Performing Test COMPILER_SUPPORT_wd981
# -- Performing Test COMPILER_SUPPORT_wd981 - Failed
# -- Performing Test COMPILER_SUPPORT_wd2304
# -- Performing Test COMPILER_SUPPORT_wd2304 - Failed
# -- Performing Test COMPILER_SUPPORT_STRICTANSI
# -- Performing Test COMPILER_SUPPORT_STRICTANSI - Failed
# -- Performing Test COMPILER_SUPPORT_Qunusedarguments
# -- Performing Test COMPILER_SUPPORT_Qunusedarguments - Success
# -- Performing Test COMPILER_SUPPORT_ansi
# -- Performing Test COMPILER_SUPPORT_ansi - Success
# -- Performing Test COMPILER_SUPPORT_OPENMP
# -- Performing Test COMPILER_SUPPORT_OPENMP - Success
# -- Looking for a Fortran compiler
# -- Looking for a Fortran compiler - /usr/bin/f95
# -- The Fortran compiler identification is GNU 11.4.0
# -- Detecting Fortran compiler ABI info
# -- Detecting Fortran compiler ABI info - done
# -- Check for working Fortran compiler: /usr/bin/f95 - skipped
# -- Found unsuitable Qt version "" from NOTFOUND
# -- Qt4 not found, so disabling the mandelbrot and opengl demos
# -- Could NOT find CHOLMOD (missing: CHOLMOD_INCLUDES CHOLMOD_LIBRARIES)
# -- Could NOT find UMFPACK (missing: UMFPACK_INCLUDES UMFPACK_LIBRARIES)
# -- Could NOT find KLU (missing: KLU_INCLUDES KLU_LIBRARIES)
# -- Could NOT find SuperLU (missing: SUPERLU_INCLUDES SUPERLU_LIBRARIES SUPERLU_VERSION_OK) (Required is at least version "4.0")
# -- Checking for one of the modules 'hwloc'
# -- A version of Pastix has been found but pastix_nompi.h does not exist in the include directory. Because Eigen tests require a version without MPI, we disable the Pastix backend.
# --
# -- Configured Eigen 3.4.0
# --
# -- Available targets (use: make TARGET):
# -- ---------+--------------------------------------------------------------
# -- Target   |   Description
# -- ---------+--------------------------------------------------------------
# -- install  | Install Eigen. Headers will be installed to:
# --          |     <CMAKE_INSTALL_PREFIX>/<INCLUDE_INSTALL_DIR>
# --          |   Using the following values:
# --          |     CMAKE_INSTALL_PREFIX: /content/sherpa-onnx/build-wasm-simd-tts/install
# --          |     INCLUDE_INSTALL_DIR:  include/eigen3
# --          |   Change the install location of Eigen headers using:
# --          |     cmake . -DCMAKE_INSTALL_PREFIX=yourprefix
# --          |   Or:
# --          |     cmake . -DINCLUDE_INSTALL_DIR=yourdir
# -- doc      | Generate the API documentation, requires Doxygen & LaTeX
# -- blas     | Build BLAS library (not the same thing as Eigen)
# -- uninstall| Remove files installed by the install target
# -- ---------+--------------------------------------------------------------
# --
# -- CMAKE_SYSTEM_NAME: Emscripten
# -- CMAKE_SYSTEM_PROCESSOR: x86
# -- location_onnxruntime_header_dir: location_onnxruntime_header_dir-NOTFOUND
# -- location_onnxruntime_lib: location_onnxruntime_lib-NOTFOUND
# -- Could not find a pre-installed onnxruntime.
# -- Downloading pre-compiled onnxruntime
# -- CMAKE_SYSTEM_NAME: Emscripten
# -- CMAKE_SYSTEM_PROCESSOR: x86
# -- CMAKE_SYSTEM_NAME: Emscripten
# -- CMAKE_SYSTEM_PROCESSOR: x86
# -- Downloading onnxruntime from https://github.com/csukuangfj/onnxruntime-libs/releases/download/v1.17.1/onnxruntime-wasm-static_lib-simd-1.17.1.zip
# -- onnxruntime is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/onnxruntime-src
# -- onnxruntime lib files: /content/sherpa-onnx/build-wasm-simd-tts/_deps/onnxruntime-src/lib/libonnxruntime.a
# -- Downloading simple-sentencepiece https://github.com/pkufool/simple-sentencepiece/archive/refs/tags/v0.7.tar.gz
# -- simple-sentencepiece is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/simple-sentencepiece-src
# -- Performing Test SBPE_COMPILER_SUPPORTS_CXX14
# -- Performing Test SBPE_COMPILER_SUPPORTS_CXX14 - Success
# -- C++ Standard version: 14
# -- ONNXRUNTIME_DIR: /content/sherpa-onnx/build-wasm-simd-tts/_deps/onnxruntime-src
# -- Downloading espeak-ng from https://github.com/csukuangfj/espeak-ng/archive/69bf6927964fb042aeb827cfdf6082a30f5802eb.zip
# -- espeak-ng is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/espeak_ng-src
# -- espeak-ng binary dir is /content/sherpa-onnx/build-wasm-simd-tts/_deps/espeak_ng-build
# -- Looking for mkstemp
# -- Looking for mkstemp - found
# -- Configuration:
# --   shared: OFF
# --   mbrola: OFF (MBROLA_BIN-NOTFOUND)
# --   libsonic: OFF (SONIC_LIB-NOTFOUND SONIC_INC-NOTFOUND)
# --   libpcaudio: OFF (PCAUDIO_LIB-NOTFOUND PCAUDIO_INC-NOTFOUND)
# --   klatt: OFF
# --   speech-player: OFF
# --   async: OFF
# -- ESPEAK_NG_DIR: /content/sherpa-onnx/build-wasm-simd-tts/_deps/espeak_ng-src
# -- Downloading piper-phonemize from https://github.com/csukuangfj/piper-phonemize/archive/dc6b5f4441bffe521047086930b0fc12686acd56.zip
# -- piper-phonemize is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/piper_phonemize-src
# -- piper-phonemize binary dir is /content/sherpa-onnx/build-wasm-simd-tts/_deps/piper_phonemize-build
# -- ESPEAK_NG_DIR: /content/sherpa-onnx/build-wasm-simd-tts/_deps/espeak_ng-src
# -- ONNXRUNTIME_DIR: /content/sherpa-onnx/build-wasm-simd-tts/_deps/onnxruntime-src
# -- Downloading cppjieba https://github.com/csukuangfj/cppjieba/archive/refs/tags/sherpa-onnx-2024-04-19.tar.gz
# -- cppjieba is downloaded to /content/sherpa-onnx/build-wasm-simd-tts/_deps/cppjieba-src
# CMake Deprecation Warning at build-wasm-simd-tts/_deps/cppjieba-src/CMakeLists.txt:3 (cmake_minimum_required):
#   Compatibility with CMake < 3.5 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value or use a ...<max> suffix to tell
#   CMake that the project does not need compatibility with older versions.
#
#
# -- CMAKE_CXX_FLAGS:
# -- CMAKE_CXX_FLAGS:
# -- Configuring done (81.2s)
# -- Generating done (0.1s)
# -- Build files have been written to: /content/sherpa-onnx/build-wasm-simd-tts
# + make -j2
# [  1%] Building C object _deps/espeak_ng-build/src/ucd-tools/CMakeFiles/ucd.dir/src/case.c.o
# [  1%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/feature-fbank.cc.o
# [  1%] Building C object _deps/espeak_ng-build/src/ucd-tools/CMakeFiles/ucd.dir/src/categories.c.o
# [  1%] Building C object _deps/espeak_ng-build/src/ucd-tools/CMakeFiles/ucd.dir/src/ctype.c.o
# [  3%] Building C object _deps/espeak_ng-build/src/ucd-tools/CMakeFiles/ucd.dir/src/proplist.c.o
# [  3%] Building C object _deps/espeak_ng-build/src/ucd-tools/CMakeFiles/ucd.dir/src/scripts.c.o
# [  3%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/feature-functions.cc.o
# [  3%] Building C object _deps/espeak_ng-build/src/ucd-tools/CMakeFiles/ucd.dir/src/tostring.c.o
# [  4%] Linking C static library ../../../../lib/libucd.a
# [  4%] Built target ucd
# [  4%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/compat.cc.o
# [  6%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/feature-window.cc.o
# [  8%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/flags.cc.o
# [  8%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/fftsg.cc.o
# [  8%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/kaldi-math.cc.o
# [  8%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/fst.cc.o
# [  9%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/mel-computations.cc.o
# [  9%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/online-feature.cc.o
# [  9%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/rfft.cc.o
# [  9%] Building CXX object _deps/kaldi_native_fbank-build/kaldi-native-fbank/csrc/CMakeFiles/kaldi-native-fbank-core.dir/whisper-feature.cc.o
# [ 11%] Linking CXX static library ../../../../lib/libkaldi-native-fbank-core.a
# [ 11%] Built target kaldi-native-fbank-core
# [ 13%] Building CXX object _deps/simple-sentencepiece-build/ssentencepiece/csrc/CMakeFiles/ssentencepiece_core.dir/ssentencepiece.cc.o
# [ 13%] Linking CXX static library ../../../../lib/libssentencepiece_core.a
# [ 13%] Built target ssentencepiece_core
# [ 13%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/properties.cc.o
# [ 14%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/symbol-table.cc.o
# [ 14%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/util.cc.o
# [ 14%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/symbol-table-ops.cc.o
# [ 14%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/mapped-file.cc.o
# [ 16%] Building CXX object _deps/openfst-build/src/lib/CMakeFiles/fst.dir/weight.cc.o
# [ 16%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/common.c.o
# [ 18%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/mnemonics.c.o
# [ 18%] Linking CXX static library ../../../../lib/libsherpa-onnx-fst.a
# [ 18%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/error.c.o
# [ 18%] Built target fst
# [ 18%] Building CXX object _deps/openfst-build/src/extensions/far/CMakeFiles/fstfar.dir/sttable.cc.o
# [ 18%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/ieee80.c.o
# [ 18%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/compiledata.c.o
# [ 19%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/compiledict.c.o
# [ 19%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/dictionary.c.o
# [ 21%] Building CXX object _deps/openfst-build/src/extensions/far/CMakeFiles/fstfar.dir/stlist.cc.o
# [ 21%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/encoding.c.o
# [ 22%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/intonation.c.o
# [ 22%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/langopts.c.o
# [ 22%] Linking CXX static library ../../../../../lib/libsherpa-onnx-fstfar.a
# [ 22%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/numbers.c.o
# [ 22%] Built target fstfar
# [ 22%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/context-fst.cc.o
# [ 22%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/phoneme.c.o
# [ 24%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/phonemelist.c.o
# [ 24%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/readclause.c.o
# [ 24%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/setlengths.c.o
# [ 26%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/soundicon.c.o
# [ 26%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/spect.c.o
# [ 26%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/ssml.c.o
# [ 27%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/synthdata.c.o
# [ 27%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/synthesize.c.o
# [ 27%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/tr_languages.c.o
# [ 27%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/translate.c.o
# [ 29%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/translateword.c.o
# [ 29%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/voices.c.o
# [ 29%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/kaldi-fst-io.cc.o
# [ 29%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/wavegen.c.o
# [ 31%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/speech.c.o
# [ 31%] Building C object _deps/espeak_ng-build/src/libespeak-ng/CMakeFiles/espeak-ng.dir/espeak_api.c.o
# [ 31%] Linking C static library ../../../../lib/libespeak-ng.a
# [ 31%] Built target espeak-ng
# [ 32%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/kaldi-holder.cc.o
# [ 32%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/kaldi-io.cc.o
# [ 32%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/kaldi-math.cc.o
# [ 32%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/kaldi-semaphore.cc.o
# [ 34%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/kaldi-table.cc.o
# [ 34%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/parse-options.cc.o
# [ 34%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/text-normalizer.cc.o
# [ 36%] Building CXX object _deps/kaldifst-build/kaldifst/csrc/CMakeFiles/kaldifst_core.dir/text-utils.cc.o
# [ 36%] Building CXX object _deps/piper_phonemize-build/CMakeFiles/piper_phonemize.dir/src/phonemize.cpp.o
# [ 37%] Building CXX object _deps/piper_phonemize-build/CMakeFiles/piper_phonemize.dir/src/phoneme_ids.cpp.o
# [ 37%] Building CXX object _deps/piper_phonemize-build/CMakeFiles/piper_phonemize.dir/src/tashkeel.cpp.o
# [ 37%] Building CXX object _deps/piper_phonemize-build/CMakeFiles/piper_phonemize.dir/src/shared.cpp.o
# [ 37%] Linking CXX static library ../../lib/libpiper_phonemize.a
# [ 37%] Linking CXX static library ../../../../lib/libsherpa-onnx-kaldifst-core.a
# [ 37%] Built target piper_phonemize
# [ 37%] Built target kaldifst_core
# [ 37%] Building CXX object _deps/kaldi_decoder-build/kaldi-decoder/csrc/CMakeFiles/kaldi-decoder-core.dir/decodable-ctc.cc.o
# [ 37%] Building CXX object _deps/kaldi_decoder-build/kaldi-decoder/csrc/CMakeFiles/kaldi-decoder-core.dir/eigen.cc.o
# [ 39%] Building CXX object _deps/kaldi_decoder-build/kaldi-decoder/csrc/CMakeFiles/kaldi-decoder-core.dir/faster-decoder.cc.o
# [ 39%] Building CXX object _deps/kaldi_decoder-build/kaldi-decoder/csrc/CMakeFiles/kaldi-decoder-core.dir/lattice-faster-decoder.cc.o
# [ 39%] Building CXX object _deps/kaldi_decoder-build/kaldi-decoder/csrc/CMakeFiles/kaldi-decoder-core.dir/lattice-simple-decoder.cc.o
# [ 40%] Building CXX object _deps/kaldi_decoder-build/kaldi-decoder/csrc/CMakeFiles/kaldi-decoder-core.dir/simple-decoder.cc.o
# [ 40%] Linking CXX static library ../../../../lib/libkaldi-decoder-core.a
# [ 40%] Built target kaldi-decoder-core
# [ 40%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/base64-decode.cc.o
# [ 40%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/cat.cc.o
# [ 42%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/circular-buffer.cc.o
# [ 42%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/context-graph.cc.o
# [ 42%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/endpoint.cc.o
# [ 44%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/features.cc.o
# [ 44%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/file-utils.cc.o
# [ 44%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/hypothesis.cc.o
# [ 44%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/keyword-spotter-impl.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/keyword-spotter-impl.cc:5:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/keyword-spotter-impl.h:17:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/keyword-spotter.h:19:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/online-stream.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-src/kaldi-decoder/csrc/faster-decoder.h:16:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# [ 45%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/keyword-spotter.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/keyword-spotter.cc:5:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/keyword-spotter.h:19:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/online-stream.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-src/kaldi-decoder/csrc/faster-decoder.h:16:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# 1 warning generated.
# [ 45%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-ctc-fst-decoder-config.cc.o
# 1 warning generated.
# [ 45%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-ctc-fst-decoder.cc.o
# [ 47%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-ctc-greedy-search-decoder.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:5:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# [ 47%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-ctc-model.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:10:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fstlib.h:33:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/compact-fst.h:19:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/cache.h:19:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:38:39: warning:
#       'rebind<fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>' is deprecated
#       [-Wdeprecated-declarations]
#    38 |       typename ArcAllocator::template rebind<VectorState<Arc, M>>::other;
#       |                                       ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:132:51: note:
#       in instantiation of template class
#       'fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>' requested here
#   132 | class VectorFstBaseImpl : public FstImpl<typename S::Arc> {
#       |                                                   ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:267:30: note:
#       in instantiation of template class
#       'fst::internal::VectorFstBaseImpl<fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>'
#       requested here
#   267 | class VectorFstImpl : public VectorFstBaseImpl<S> {
#       |                              ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/mutable-fst.h:267:55: note:
#       in instantiation of template class
#       'fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>'
#       requested here
#   267 | template <class Impl, class FST = MutableFst<typename Impl::Arc>>
#       |                                                       ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:430:26: note:
#       in instantiation of default argument for
#       'ImplToMutableFst<internal::VectorFstImpl<VectorState<ArcTpl<TropicalWeightTpl<float>>,
#       allocator<ArcTpl<TropicalWeightTpl<float>>>>>>' required here
#   430 | class VectorFst : public ImplToMutableFst<internal::VectorFstImpl<S>> {
#       |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:44:23: note:
#       in instantiation of template class
#       'fst::VectorFst<fst::ArcTpl<fst::TropicalWeightTpl<float>>>' requested here
#    44 |     decode_fst = fst::VectorFst<fst::StdArc>::Read(is, ropts);
#       |                       ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/allocator.h:151:10: note:
#       'rebind<fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>' has been explicitly
#       marked deprecated here
#   151 |   struct _LIBCPP_DEPRECATED_IN_CXX17 rebind {
#       |          ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:10:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fstlib.h:33:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/compact-fst.h:19:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/cache.h:19:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:38:39: warning:
#       'rebind<fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>' is deprecated
#       [-Wdeprecated-declarations]
#    38 |       typename ArcAllocator::template rebind<VectorState<Arc, M>>::other;
#       |                                       ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:132:51: note:
#       in instantiation of template class
#       'fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>' requested here
#   132 | class VectorFstBaseImpl : public FstImpl<typename S::Arc> {
#       |                                                   ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:267:30: note:
#       in instantiation of template class
#       'fst::internal::VectorFstBaseImpl<fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>'
#       requested here
#   267 | class VectorFstImpl : public VectorFstBaseImpl<S> {
#       |                              ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/mutable-fst.h:267:55: note:
#       in instantiation of template class
#       'fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>'
#       requested here
#   267 | template <class Impl, class FST = MutableFst<typename Impl::Arc>>
#       |                                                       ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:430:26: note:
#       in instantiation of default argument for
#       'ImplToMutableFst<internal::VectorFstImpl<VectorState<ArcTpl<LatticeWeightTpl<float>>,
#       allocator<ArcTpl<LatticeWeightTpl<float>>>>>>' required here
#   430 | class VectorFst : public ImplToMutableFst<internal::VectorFstImpl<S>> {
#       |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:80:35: note:
#       in instantiation of template class 'fst::VectorFst<fst::ArcTpl<fst::LatticeWeightTpl<float>>>'
#       requested here
#    80 |   fst::VectorFst<fst::LatticeArc> decoded;  // linear FST.
#       |                                   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/allocator.h:151:10: note:
#       'rebind<fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>' has been explicitly
#       marked deprecated here
#   151 |   struct _LIBCPP_DEPRECATED_IN_CXX17 rebind {
#       |          ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:5:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.h:11:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:910:38: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   910 |   bool Unique() const { return impl_.unique(); }
#       |                                      ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/mutable-fst.h:383:10: note:
#       in instantiation of member function
#       'fst::ImplToFst<fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>,
#       fst::MutableFst<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>::Unique' requested here
#   383 |     if (!Unique()) SetImpl(std::make_shared<Impl>(*this));
#       |          ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/mutable-fst.h:277:5: note:
#       in instantiation of member function
#       'fst::ImplToMutableFst<fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>>::MutateCheck'
#       requested here
#   277 |     MutateCheck();
#       |     ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:515:12: note:
#       in instantiation of member function
#       'fst::ImplToMutableFst<fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::TropicalWeightTpl<float>>>>>::SetStart'
#       requested here
#   515 |   explicit VectorFst(std::shared_ptr<Impl> impl)
#       |            ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/vector-fst.h:472:23: note:
#       in instantiation of member function
#       'fst::VectorFst<fst::ArcTpl<fst::TropicalWeightTpl<float>>>::VectorFst' requested here
#   472 |     return impl ? new VectorFst<Arc, State>(std::shared_ptr<Impl>(impl))
#       |                       ^
# /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:44:47: note:
#       in instantiation of member function
#       'fst::VectorFst<fst::ArcTpl<fst::TropicalWeightTpl<float>>>::Read' requested here
#    44 |     decode_fst = fst::VectorFst<fst::StdArc>::Read(is, ropts);
#       |                                               ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# [ 47%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-lm-config.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:5:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.h:11:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:910:38: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   910 |   bool Unique() const { return impl_.unique(); }
#       |                                      ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/mutable-fst.h:383:10: note:
#       in instantiation of member function
#       'fst::ImplToFst<fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>,
#       fst::MutableFst<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>::Unique' requested here
#   383 |     if (!Unique()) SetImpl(std::make_shared<Impl>(*this));
#       |          ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/mutable-fst.h:277:5: note:
#       in instantiation of member function
#       'fst::ImplToMutableFst<fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>>::MutateCheck'
#       requested here
#   277 |     MutateCheck();
#       |     ^
# /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.cc:80:35: note:
#       in instantiation of member function
#       'fst::ImplToMutableFst<fst::internal::VectorFstImpl<fst::VectorState<fst::ArcTpl<fst::LatticeWeightTpl<float>>>>>::SetStart'
#       requested here
#    80 |   fst::VectorFst<fst::LatticeArc> decoded;  // linear FST.
#       |                                   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# [ 49%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-lm.cc.o
# 5 warnings generated.
# [ 49%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-model-config.cc.o
# [ 49%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-nemo-enc-dec-ctc-model-config.cc.o
# [ 49%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-nemo-enc-dec-ctc-model.cc.o
# [ 50%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-paraformer-greedy-search-decoder.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-nemo-enc-dec-ctc-model.cc:9:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/session.h:15:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/speaker-embedding-extractor.h:17:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/online-stream.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-src/kaldi-decoder/csrc/faster-decoder.h:16:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# [ 50%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-paraformer-model-config.cc.o
# 1 warning generated.
# [ 50%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-paraformer-model.cc.o
# [ 52%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-recognizer-impl.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-paraformer-model.cc:13:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/session.h:15:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/speaker-embedding-extractor.h:17:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/online-stream.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-src/kaldi-decoder/csrc/faster-decoder.h:16:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-recognizer-impl.cc:11:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-recognizer-ctc-impl.h:21:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-ctc-fst-decoder.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# ...
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# /content/sherpa-onnx/sherpa-onnx/csrc/offline-tts-character-frontend.cc:112:8: warning:
#       'wstring_convert<std::codecvt_utf8<char32_t>, char32_t>' is deprecated
#       [-Wdeprecated-declarations]
#   112 |   std::wstring_convert<std::codecvt_utf8<char32_t>, char32_t> conv;
#       |        ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/locale:3114:28: note:
#       'wstring_convert<std::codecvt_utf8<char32_t>, char32_t>' has been explicitly marked deprecated
#       here
#  3114 | class _LIBCPP_TEMPLATE_VIS _LIBCPP_DEPRECATED_IN_CXX17 wstring_convert {
#       |                            ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# [ 95%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-tts-impl.cc.o
# 4 warnings generated.
# [ 95%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-tts-model-config.cc.o
# [ 95%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-tts-vits-model-config.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-tts-impl.cc:9:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-tts-vits-impl.h:19:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/extensions/far/far.h:15:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-tts-impl.cc:9:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-tts-vits-impl.h:19:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/extensions/far/far.h:435:19: warning:
#       class with destructor marked 'final' cannot be inherited from [-Wfinal-dtor-non-final-class]
#   358 |   ~FstFarReader() final {
#       |                   ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/extensions/far/far.h:485:12: note:
#       in instantiation of template class
#       'fst::FstFarReader<fst::ArcTpl<fst::TropicalWeightTpl<float>>>' requested here
#   485 |     return FstFarReader<Arc>::Open(filename);
#       |            ^
# /content/sherpa-onnx/sherpa-onnx/csrc/offline-tts-vits-impl.h:68:42: note: in
#       instantiation of member function
#       'fst::FarReader<fst::ArcTpl<fst::TropicalWeightTpl<float>>>::Open' requested here
#    68 |             fst::FarReader<fst::StdArc>::Open(f));
#       |                                          ^
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/extensions/far/far.h:358:7: note:
#       mark 'fst::FstFarReader<fst::ArcTpl<fst::TropicalWeightTpl<float>>>' as 'final' to silence
#       this warning
#   358 | class FstFarReader : public FarReader<A> {
#       |       ^
# [ 96%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-tts-vits-model.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/offline-tts-vits-model.cc:14:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/session.h:15:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/speaker-embedding-extractor.h:17:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/online-stream.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-src/kaldi-decoder/csrc/faster-decoder.h:16:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# 2 warnings generated.
# [ 96%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/offline-tts.cc.o
# [ 96%] Building CXX object sherpa-onnx/csrc/CMakeFiles/sherpa-onnx-core.dir/piper-phonemize-lexicon.cc.o
# 1 warning generated.
# /content/sherpa-onnx/sherpa-onnx/csrc/piper-phonemize-lexicon.cc:33:29: warning:
#       'codecvt_utf8<char32_t>' is deprecated [-Wdeprecated-declarations]
#    33 |   std::wstring_convert<std::codecvt_utf8<char32_t>, char32_t> conv;
#       |                             ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/codecvt:194:28: note:
#       'codecvt_utf8<char32_t>' has been explicitly marked deprecated here
#   194 | class _LIBCPP_TEMPLATE_VIS _LIBCPP_DEPRECATED_IN_CXX17 codecvt_utf8 : public __codecvt_utf8<_Elem> {
#       |                            ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# /content/sherpa-onnx/sherpa-onnx/csrc/piper-phonemize-lexicon.cc:33:8: warning:
#       'wstring_convert<std::codecvt_utf8<char32_t>, char32_t>' is deprecated
#       [-Wdeprecated-declarations]
#    33 |   std::wstring_convert<std::codecvt_utf8<char32_t>, char32_t> conv;
#       |        ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/locale:3114:28: note:
#       'wstring_convert<std::codecvt_utf8<char32_t>, char32_t>' has been explicitly marked deprecated
#       here
#  3114 | class _LIBCPP_TEMPLATE_VIS _LIBCPP_DEPRECATED_IN_CXX17 wstring_convert {
#       |                            ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# 2 warnings generated.
# [ 98%] Linking CXX static library ../../lib/libsherpa-onnx-core.a
# [ 98%] Built target sherpa-onnx-core
# [100%] Building CXX object sherpa-onnx/c-api/CMakeFiles/sherpa-onnx-c-api.dir/c-api.cc.o
# In file included from /content/sherpa-onnx/sherpa-onnx/c-api/c-api.cc:16:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/keyword-spotter.h:19:
# In file included from /content/sherpa-onnx/sherpa-onnx/csrc/online-stream.h:11:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/kaldi_decoder-src/kaldi-decoder/csrc/faster-decoder.h:16:
# In file included from /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/fst.h:31:
# /content/sherpa-onnx/build-wasm-simd-tts/_deps/openfst-src/src/include/fst/symbol-table.h:388:16: warning:
#       'unique' is deprecated [-Wdeprecated-declarations]
#   388 |     if (!impl_.unique()) impl_.reset(new internal::SymbolTableImpl(*impl_));
#       |                ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__memory/shared_ptr.h:730:3: note:
#       'unique' has been explicitly marked deprecated here
#   730 |   _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_HIDE_FROM_ABI bool unique() const _NOEXCEPT { return u...
#       |   ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:1002:41: note:
#       expanded from macro '_LIBCPP_DEPRECATED_IN_CXX17'
#  1002 | #    define _LIBCPP_DEPRECATED_IN_CXX17 _LIBCPP_DEPRECATED
#       |                                         ^
# /content/emsdk/upstream/emscripten/cache/sysroot/include/c++/v1/__config:975:49: note:
#       expanded from macro '_LIBCPP_DEPRECATED'
#   975 | #      define _LIBCPP_DEPRECATED __attribute__((__deprecated__))
#       |                                                 ^
# 1 warning generated.
# [100%] Linking CXX static library ../../lib/libsherpa-onnx-c-api.a
# [100%] Built target sherpa-onnx-c-api
# [100%] Building CXX object wasm/tts/CMakeFiles/sherpa-onnx-wasm-main-tts.dir/sherpa-onnx-wasm-main-tts.cc.o
# em++: warning: linker setting ignored during compilation: 'FORCE_FILESYSTEM' [-Wunused-command-line-argument]
# em++: warning: linker setting ignored during compilation: 'INITIAL_MEMORY' [-Wunused-command-line-argument]
# em++: warning: linker setting ignored during compilation: 'ALLOW_MEMORY_GROWTH' [-Wunused-command-line-argument]
# em++: warning: linker setting ignored during compilation: 'STACK_SIZE' [-Wunused-command-line-argument]
# em++: warning: linker setting ignored during compilation: 'EXPORTED_FUNCTIONS' [-Wunused-command-line-argument]
# em++: warning: linker setting ignored during compilation: 'EXPORTED_RUNTIME_METHODS' [-Wunused-command-line-argument]
# em++: warning: linker flag ignored during compilation: '--preload-file' [-Wunused-command-line-argument]
# [100%] Linking CXX executable ../../bin/sherpa-onnx-wasm-main-tts.js
# em++: warning: ignoring unsupported linker flag: `-rpath` [-Wlinkflags]
# cache:INFO: generating system asset: symbol_lists/1afcc021364259cc971ab97b9bf9d8ff48d1c671.json... (this will be cached in "/content/emsdk/upstream/emscripten/cache/symbol_lists/1afcc021364259cc971ab97b9bf9d8ff48d1c671.json" for subsequent builds)
# cache:INFO:  - ok
# [100%] Built target sherpa-onnx-wasm-main-tts
# + make install
# [  4%] Built target ucd
# [ 18%] Built target espeak-ng
# [ 19%] Built target piper_phonemize
# [ 24%] Built target kaldi-native-fbank-core
# [ 29%] Built target fst
# [ 31%] Built target fstfar
# [ 36%] Built target kaldifst_core
# [ 39%] Built target kaldi-decoder-core
# [ 40%] Built target ssentencepiece_core
# [ 98%] Built target sherpa-onnx-core
# [100%] Built target sherpa-onnx-c-api
# [100%] Built target sherpa-onnx-wasm-main-tts
# Install the project...
# -- Install configuration: "Release"
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libkaldi-native-fbank-core.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libkaldi-decoder-core.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libsherpa-onnx-kaldifst-core.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libsherpa-onnx-fst.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libsherpa-onnx-fstfar.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libonnxruntime.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libssentencepiece_core.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libespeak-ng.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libucd.a
# -- Up-to-date: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libucd.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libpiper_phonemize.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/./sherpa-onnx.pc
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/pkgconfig/espeak-ng.pc
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/share/vim/vimfiles/ftdetect
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/share/vim/vimfiles/ftdetect/espeakfiletype.vim
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/share/vim/vimfiles/syntax
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/share/vim/vimfiles/syntax/espeaklist.vim
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/share/vim/vimfiles/syntax/espeakrules.vim
# -- Up-to-date: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libucd.a
# -- Up-to-date: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libespeak-ng.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libsherpa-onnx-core.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/lib/libsherpa-onnx-c-api.a
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/include/sherpa-onnx/c-api/c-api.h
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-wasm-main-tts.js
# -- Up-to-date: /content/sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-wasm-main-tts.js
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/index.html
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-tts.js
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/app-tts.js
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-wasm-main-tts.wasm
# -- Installing: /content/sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-wasm-main-tts.data
# + ls -lh install/bin/wasm/tts
# total 104M
# -rw-r--r-- 1 root root 5.3K May 23 09:13 app-tts.js
# -rw-r--r-- 1 root root 1.3K May 23 09:13 index.html
# -rw-r--r-- 1 root root 6.5K May 23 09:13 sherpa-onnx-tts.js
# -rw-r--r-- 1 root root  93M May 23 09:22 sherpa-onnx-wasm-main-tts.data
# -rw-r--r-- 1 root root 115K May 23 09:29 sherpa-onnx-wasm-main-tts.js
# -rw-r--r-- 1 root root  11M May 23 09:29 sherpa-onnx-wasm-main-tts.wasm

# %%
# %%shell
#
# ls -lh
# echo "---"
# ls -lh sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts
# Out:
# total 12K
# drwxr-xr-x 12 root root 4.0K May 23 09:10 emsdk
# drwxr-xr-x  1 root root 4.0K May 21 13:23 sample_data
# drwxr-xr-x 24 root root 4.0K May 23 09:13 sherpa-onnx
# ---
# total 104M
# -rw-r--r-- 1 root root 5.3K May 23 09:13 app-tts.js
# -rw-r--r-- 1 root root 1.3K May 23 09:13 index.html
# -rw-r--r-- 1 root root 6.5K May 23 09:13 sherpa-onnx-tts.js
# -rw-r--r-- 1 root root  93M May 23 09:22 sherpa-onnx-wasm-main-tts.data
# -rw-r--r-- 1 root root 115K May 23 09:29 sherpa-onnx-wasm-main-tts.js
# -rw-r--r-- 1 root root  11M May 23 09:29 sherpa-onnx-wasm-main-tts.wasm

# %% [markdown]
# ## Download the generated files to your local computer

# %%
# %%shell
#
# mkdir -p sherpa-onnx-wasm-tts
# cp -v sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/* ./sherpa-onnx-wasm-tts
#
# tar cjvf ./sherpa-onnx-wasm-tts.tar.bz2 ./sherpa-onnx-wasm-tts
# Out:
# 'sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/app-tts.js' -> './sherpa-onnx-wasm-tts/app-tts.js'
# 'sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/index.html' -> './sherpa-onnx-wasm-tts/index.html'
# 'sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-tts.js' -> './sherpa-onnx-wasm-tts/sherpa-onnx-tts.js'
# 'sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-wasm-main-tts.data' -> './sherpa-onnx-wasm-tts/sherpa-onnx-wasm-main-tts.data'
# 'sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-wasm-main-tts.js' -> './sherpa-onnx-wasm-tts/sherpa-onnx-wasm-main-tts.js'
# 'sherpa-onnx/build-wasm-simd-tts/install/bin/wasm/tts/sherpa-onnx-wasm-main-tts.wasm' -> './sherpa-onnx-wasm-tts/sherpa-onnx-wasm-main-tts.wasm'
# ./sherpa-onnx-wasm-tts/
# ./sherpa-onnx-wasm-tts/sherpa-onnx-wasm-main-tts.wasm
# ./sherpa-onnx-wasm-tts/index.html
# ./sherpa-onnx-wasm-tts/sherpa-onnx-wasm-main-tts.data
# ./sherpa-onnx-wasm-tts/sherpa-onnx-wasm-main-tts.js
# ./sherpa-onnx-wasm-tts/sherpa-onnx-tts.js
# ./sherpa-onnx-wasm-tts/app-tts.js

# %%
# %%shell
# ls -lh
# Out:
# total 81M
# drwxr-xr-x 12 root root 4.0K May 23 09:10 emsdk
# drwxr-xr-x  1 root root 4.0K May 21 13:23 sample_data
# drwxr-xr-x 24 root root 4.0K May 23 09:13 sherpa-onnx
# drwxr-xr-x  2 root root 4.0K May 23 09:33 sherpa-onnx-wasm-tts
# -rw-r--r--  1 root root  81M May 23 09:33 sherpa-onnx-wasm-tts.tar.bz2

# %%
from google.colab import files
files.download('sherpa-onnx-wasm-tts.tar.bz2')

# %% [markdown]
# Please follow https://k2-fsa.github.io/sherpa/onnx/tts/wasm/build.html for how to use the downloaded files.
